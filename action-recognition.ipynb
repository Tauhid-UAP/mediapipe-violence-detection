# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_pose = mp.solutions.pose

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(
        image,
        results.pose_landmarks,
        mp_pose.POSE_CONNECTIONS,
        landmark_drawing_spec=mp_drawing_styles.get_default_pose_landmarks_style())

# %%
cap = cv2.VideoCapture(0)
results = None
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, pose)
        print(results)
        
        # Draw landmarks
        draw_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
len(results.pose_landmarks.landmark)
# Out:
# 33

# %%
def extract_keypoints(results):
    pose_array = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33 * 4)
    return pose_array

# %%
DATA_PATH = os.path.join('action-training-data')

# Actions that we try to detect
actions = np.array(['Passive', 'Right Jab', 'Left Jab', 'Left Cross', 'Right Cross'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# %%
# for action in actions:
#     for sequence_num in range(no_sequences):
#         try:
#             os.makedirs(os.path.join(DATA_PATH, action, str(sequence_num)))
#         except Exception as e:
#             print('Exception: ', e)

# %%
time.sleep(5)

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    action = actions[2]
    # Loop through sequences aka videos
    for sequence in range(no_sequences):
        # Loop through video length aka sequence length
        for frame_num in range(sequence_length):

            # Read feed
            ret, frame = cap.read()

            # Make detections
            image, results = mediapipe_detection(frame, pose)

            # Draw landmarks
            draw_landmarks(image, results)

            if frame_num == 0: 
                cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                # Show to screen
                cv2.imshow('OpenCV Feed', image)
                cv2.waitKey(2000)
            else: 
                cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                # Show to screen
                cv2.imshow('OpenCV Feed', image)

            # NEW Export keypoints
            keypoints = extract_keypoints(results)
            npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
            np.save(npy_path, keypoints)

            # Break gracefully
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'Passive': 0,
#  'Right Jab': 1,
#  'Left Jab': 2,
#  'Left Cross': 3,
#  'Right Cross': 4}

# %%
sequences, labels = [], []
for action in actions[0: 3]:
    for sequence_num in range(no_sequences):
        sequence = []
        for frame_num in range(sequence_length):
            pose_points = np.load(os.path.join(DATA_PATH, action, str(sequence_num), "{}.npy".format(frame_num)))
            sequence.append(pose_points)
        sequences.append(sequence)
        labels.append(label_map[action])

# %%
x = np.array(sequences)

# %%
x.shape
# Out:
# (90, 30, 132)

# %%
y = to_categorical(labels).astype(int)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (5, 3)

# %%
x_test.shape
# Out:
# (5, 30, 132)

# %%
actions.shape
# Out:
# (5,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,132)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0] - 2, activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(x_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 3s 55ms/step - loss: 1.0994 - categorical_accuracy: 0.3882
# Epoch 2/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0933 - categorical_accuracy: 0.2235
# Epoch 3/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0341 - categorical_accuracy: 0.5412
# Epoch 4/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.8663 - categorical_accuracy: 0.5529
# Epoch 5/2000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5777 - categorical_accuracy: 0.6588
# Epoch 6/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0902 - categorical_accuracy: 0.7647
# Epoch 7/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.6685 - categorical_accuracy: 0.7059
# Epoch 8/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6352 - categorical_accuracy: 0.7412
# Epoch 9/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.7786 - categorical_accuracy: 0.6588
# Epoch 10/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7172 - categorical_accuracy: 0.6588
# Epoch 11/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7550 - categorical_accuracy: 0.6588
# Epoch 12/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6685 - categorical_accuracy: 0.6588
# Epoch 13/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6740 - categorical_accuracy: 0.6588
# Epoch 14/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.6023 - categorical_accuracy: 0.6588
# Epoch 15/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5374 - categorical_accuracy: 0.6588
# Epoch 16/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.4954 - categorical_accuracy: 0.6588
# Epoch 17/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.4197 - categorical_accuracy: 0.7059
# Epoch 18/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3562 - categorical_accuracy: 0.9059
# Epoch 19/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2899 - categorical_accuracy: 0.8706
# Epoch 20/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1344 - categorical_accuracy: 0.9647
# Epoch 21/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.5974 - categorical_accuracy: 0.8706
# Epoch 22/2000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.4828 - categorical_accuracy: 0.9294
# Epoch 23/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3136 - categorical_accuracy: 0.8000
# Epoch 24/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.4164 - categorical_accuracy: 0.6706
# Epoch 25/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.4544 - categorical_accuracy: 0.7529
# Epoch 26/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.4108 - categorical_accuracy: 0.9294
# Epoch 27/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.3146 - categorical_accuracy: 0.7765
# Epoch 28/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.3534 - categorical_accuracy: 0.8235
# Epoch 29/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.3484 - categorical_accuracy: 0.9529
# Epoch 30/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2425 - categorical_accuracy: 0.9882
# Epoch 31/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.2326 - categorical_accuracy: 0.9647
# Epoch 32/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2499 - categorical_accuracy: 0.9529
# Epoch 33/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.1166 - categorical_accuracy: 1.00 - 0s 58ms/step - loss: 0.1166 - categorical_accuracy: 1.0000
# Epoch 34/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1825 - categorical_accuracy: 0.9765
# Epoch 35/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3095 - categorical_accuracy: 0.8706
# Epoch 36/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1418 - categorical_accuracy: 0.9882
# Epoch 37/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1378 - categorical_accuracy: 0.9647
# Epoch 38/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0886 - categorical_accuracy: 1.0000
# Epoch 39/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0837 - categorical_accuracy: 1.0000
# Epoch 40/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0465 - categorical_accuracy: 1.0000
# Epoch 41/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0149 - categorical_accuracy: 1.0000
# Epoch 42/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2048 - categorical_accuracy: 0.9529
# Epoch 43/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.5663 - categorical_accuracy: 0.7529
# Epoch 44/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3403 - categorical_accuracy: 0.8588
# Epoch 45/2000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2175 - categorical_accuracy: 0.9294
# Epoch 46/2000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2405 - categorical_accuracy: 0.9882
# Epoch 47/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3255 - categorical_accuracy: 0.9412
# Epoch 48/2000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2084 - categorical_accuracy: 0.9882
# Epoch 49/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1935 - categorical_accuracy: 0.9882
# Epoch 50/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1967 - categorical_accuracy: 0.9529
# Epoch 51/2000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.1539 - categorical_accuracy: 1.0000
# Epoch 52/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.1186 - categorical_accuracy: 1.0000
# Epoch 53/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.1062 - categorical_accuracy: 1.0000
# Epoch 54/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0409 - categorical_accuracy: 1.0000
# Epoch 55/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0094 - categorical_accuracy: 1.0000
# Epoch 56/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.3971e-04 - categorical_accuracy: 1.0000
# Epoch 57/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.5519 - categorical_accuracy: 0.9765
# Epoch 58/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 9.5777 - categorical_accuracy: 0.8471
# Epoch 59/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.7446 - categorical_accuracy: 0.6471
# Epoch 60/2000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8306 - categorical_accuracy: 0.3882
# Epoch 61/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.3372 - categorical_accuracy: 0.3882
# Epoch 62/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.7456 - categorical_accuracy: 0.6235
# Epoch 63/2000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.7792 - categorical_accuracy: 0.6588
# Epoch 64/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.7596 - categorical_accuracy: 0.6000
# Epoch 65/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6795 - categorical_accuracy: 0.6588
# Epoch 66/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.0217 - categorical_accuracy: 0.3412
# Epoch 67/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.8545 - categorical_accuracy: 0.5294
# Epoch 68/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.6195 - categorical_accuracy: 0.6588
# Epoch 69/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.6263 - categorical_accuracy: 0.6471
# Epoch 70/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6270 - categorical_accuracy: 0.6353
# Epoch 71/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5531 - categorical_accuracy: 0.6471
# Epoch 72/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.4839 - categorical_accuracy: 0.6588
# Epoch 73/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.4281 - categorical_accuracy: 0.6235
# Epoch 74/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.4907 - categorical_accuracy: 0.7882
# Epoch 75/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.4864 - categorical_accuracy: 0.6706
# Epoch 76/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.4148 - categorical_accuracy: 0.6471
# Epoch 77/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.4864 - categorical_accuracy: 0.6588
# Epoch 78/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3563 - categorical_accuracy: 0.7882
# Epoch 79/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.3881 - categorical_accuracy: 1.00 - 0s 65ms/step - loss: 0.3510 - categorical_accuracy: 1.0000
# Epoch 80/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2065 - categorical_accuracy: 1.0000
# Epoch 81/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1107 - categorical_accuracy: 0.9882
# Epoch 82/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1727 - categorical_accuracy: 0.9647
# Epoch 83/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.2830 - categorical_accuracy: 0.8824
# Epoch 84/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.1032 - categorical_accuracy: 0.9882
# Epoch 85/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.2363 - categorical_accuracy: 0.9647
# Epoch 86/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.1111 - categorical_accuracy: 0.9765
# Epoch 87/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.1017 - categorical_accuracy: 0.9647
# Epoch 88/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0522 - categorical_accuracy: 0.9647
# Epoch 89/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0816 - categorical_accuracy: 0.9882
# Epoch 90/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0120 - categorical_accuracy: 1.0000
# Epoch 91/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0035 - categorical_accuracy: 1.0000
# Epoch 92/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.1342 - categorical_accuracy: 0.9882
# Epoch 93/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.4826 - categorical_accuracy: 0.7412
# Epoch 94/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.6223 - categorical_accuracy: 0.7882
# Epoch 95/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.5048 - categorical_accuracy: 0.7412
# Epoch 96/2000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.6489 - categorical_accuracy: 0.6706
# Epoch 97/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6927 - categorical_accuracy: 0.6471
# Epoch 98/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6249 - categorical_accuracy: 0.7059
# Epoch 99/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.5414 - categorical_accuracy: 0.7765
# Epoch 100/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.4447 - categorical_accuracy: 0.8941
# Epoch 101/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3778 - categorical_accuracy: 0.9412
# Epoch 102/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3296 - categorical_accuracy: 0.9176
# Epoch 103/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3448 - categorical_accuracy: 0.8824
# Epoch 104/2000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3182 - categorical_accuracy: 0.8824
# Epoch 105/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.3235 - categorical_accuracy: 0.9059
# Epoch 106/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2672 - categorical_accuracy: 0.9765
# Epoch 107/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.2538 - categorical_accuracy: 0.9882
# Epoch 108/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.2359 - categorical_accuracy: 0.9882
# Epoch 109/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.2163 - categorical_accuracy: 0.9882
# Epoch 110/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.1965 - categorical_accuracy: 0.9882
# Epoch 111/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.1688 - categorical_accuracy: 0.9882
# Epoch 112/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.1378 - categorical_accuracy: 1.0000
# Epoch 113/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0971 - categorical_accuracy: 1.0000
# Epoch 114/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0464 - categorical_accuracy: 1.0000
# Epoch 115/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0326 - categorical_accuracy: 0.9882
# Epoch 116/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0117 - categorical_accuracy: 1.0000
# Epoch 117/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0058 - categorical_accuracy: 1.0000
# Epoch 118/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0092 - categorical_accuracy: 1.0000
# Epoch 119/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 120/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0072 - categorical_accuracy: 1.0000
# Epoch 121/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0044 - categorical_accuracy: 1.0000
# Epoch 122/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 123/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 124/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 125/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 8.2839e-04 - categorical_accuracy: 1.0000
# Epoch 126/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0010 - categorical_accuracy: 1.0000
# Epoch 127/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 128/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 9.1765e-04 - categorical_accuracy: 1.0000
# Epoch 129/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 5.4550e-04 - categorical_accuracy: 1.0000
# Epoch 130/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 4.9216e-04 - categorical_accuracy: 1.0000
# Epoch 131/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 4.8030e-04 - categorical_accuracy: 1.0000
# Epoch 132/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 3.9853e-04 - categorical_accuracy: 1.0000
# Epoch 133/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 2.7063e-04 - categorical_accuracy: 1.0000
# Epoch 134/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.1610e-04 - categorical_accuracy: 1.0000
# Epoch 135/2000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.9986e-04 - categorical_accuracy: 1.0000
# Epoch 136/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.7464e-04 - categorical_accuracy: 1.0000
# Epoch 137/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.4150e-04 - categorical_accuracy: 1.0000
# Epoch 138/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.2526e-04 - categorical_accuracy: 1.0000
# Epoch 139/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.0493e-04 - categorical_accuracy: 1.0000
# Epoch 140/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 8.7466e-05 - categorical_accuracy: 1.0000
# Epoch 141/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 7.3191e-05 - categorical_accuracy: 1.0000
# Epoch 142/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 6.2154e-05 - categorical_accuracy: 1.0000
# Epoch 143/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 4.9398e-05 - categorical_accuracy: 1.0000
# Epoch 144/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.3287e-05 - categorical_accuracy: 1.0000
# Epoch 145/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.0891e-05 - categorical_accuracy: 1.0000
# Epoch 146/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 3.4486e-05 - categorical_accuracy: 1.0000
# Epoch 147/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 3.0826e-05 - categorical_accuracy: 1.0000
# Epoch 148/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.7152e-05 - categorical_accuracy: 1.0000
# Epoch 149/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.4383e-05 - categorical_accuracy: 1.0000
# Epoch 150/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.1647e-05 - categorical_accuracy: 1.0000
# Epoch 151/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.0224e-05 - categorical_accuracy: 1.0000
# Epoch 152/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.8884e-05 - categorical_accuracy: 1.0000
# Epoch 153/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.7191e-05 - categorical_accuracy: 1.0000
# Epoch 154/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.5943e-05 - categorical_accuracy: 1.0000
# Epoch 155/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.4756e-05 - categorical_accuracy: 1.0000
# Epoch 156/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.4377e-05 - categorical_accuracy: 1.0000
# Epoch 157/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.3333e-05 - categorical_accuracy: 1.0000
# Epoch 158/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.2239e-05 - categorical_accuracy: 1.0000
# Epoch 159/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.1599e-05 - categorical_accuracy: 1.0000
# Epoch 160/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.0973e-05 - categorical_accuracy: 1.0000
# Epoch 161/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.0593e-05 - categorical_accuracy: 1.0000
# Epoch 162/2000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.0261e-05 - categorical_accuracy: 1.0000
# Epoch 163/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 9.7856e-06 - categorical_accuracy: 1.0000
# Epoch 164/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 9.0608e-06 - categorical_accuracy: 1.0000
# Epoch 165/2000
# 3/3 [==============================] - 0s 50ms/step - loss: 8.7159e-06 - categorical_accuracy: 1.0000
# Epoch 166/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 8.4411e-06 - categorical_accuracy: 1.0000
# Epoch 167/2000
# 3/3 [==============================] - 0s 78ms/step - loss: 7.9659e-06 - categorical_accuracy: 1.0000
# Epoch 168/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 7.7920e-06 - categorical_accuracy: 1.0000
# Epoch 169/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 7.3392e-06 - categorical_accuracy: 1.0000
# Epoch 170/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 7.1864e-06 - categorical_accuracy: 1.0000
# Epoch 171/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 6.8471e-06 - categorical_accuracy: 1.0000
# Epoch 172/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 6.6592e-06 - categorical_accuracy: 1.0000
# Epoch 173/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 6.4321e-06 - categorical_accuracy: 1.0000
# Epoch 174/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 6.1951e-06 - categorical_accuracy: 1.0000
# Epoch 175/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 6.0409e-06 - categorical_accuracy: 1.0000
# Epoch 176/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 5.8054e-06 - categorical_accuracy: 1.0000
# Epoch 177/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 5.6680e-06 - categorical_accuracy: 1.0000
# Epoch 178/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 5.5095e-06 - categorical_accuracy: 1.0000
# Epoch 179/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 5.3974e-06 - categorical_accuracy: 1.0000
# Epoch 180/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 5.2375e-06 - categorical_accuracy: 1.0000
# Epoch 181/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 5.1183e-06 - categorical_accuracy: 1.0000
# Epoch 182/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.9977e-06 - categorical_accuracy: 1.0000
# Epoch 183/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.9585e-06 - categorical_accuracy: 1.0000
# Epoch 184/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 4.8071e-06 - categorical_accuracy: 1.0000
# Epoch 185/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.7552e-06 - categorical_accuracy: 1.0000
# Epoch 186/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.6080e-06 - categorical_accuracy: 1.0000
# Epoch 187/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.5322e-06 - categorical_accuracy: 1.0000
# Epoch 188/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.4523e-06 - categorical_accuracy: 1.0000
# Epoch 189/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.3906e-06 - categorical_accuracy: 1.0000
# Epoch 190/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 4.2644e-06 - categorical_accuracy: 1.0000
# Epoch 191/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 4.2350e-06 - categorical_accuracy: 1.0000
# Epoch 192/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 4.1312e-06 - categorical_accuracy: 1.0000
# Epoch 193/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 4.0401e-06 - categorical_accuracy: 1.0000
# Epoch 194/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 3.9728e-06 - categorical_accuracy: 1.0000
# Epoch 195/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 3.8999e-06 - categorical_accuracy: 1.0000
# Epoch 196/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 3.8199e-06 - categorical_accuracy: 1.0000
# Epoch 197/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 3.7694e-06 - categorical_accuracy: 1.0000
# Epoch 198/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 3.6783e-06 - categorical_accuracy: 1.0000
# Epoch 199/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 3.6348e-06 - categorical_accuracy: 1.0000
# Epoch 200/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.5689e-06 - categorical_accuracy: 1.0000
# Epoch 201/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 3.5058e-06 - categorical_accuracy: 1.0000
# Epoch 202/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 3.4413e-06 - categorical_accuracy: 1.0000
# Epoch 203/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 3.3740e-06 - categorical_accuracy: 1.0000
# Epoch 204/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 3.3263e-06 - categorical_accuracy: 1.0000
# Epoch 205/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 3.2857e-06 - categorical_accuracy: 1.0000
# Epoch 206/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 3.2282e-06 - categorical_accuracy: 1.0000
# Epoch 207/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 3.1945e-06 - categorical_accuracy: 1.0000
# Epoch 208/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 3.1356e-06 - categorical_accuracy: 1.0000
# Epoch 209/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 3.0936e-06 - categorical_accuracy: 1.0000
# Epoch 210/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 3.0487e-06 - categorical_accuracy: 1.0000
# Epoch 211/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 3.0080e-06 - categorical_accuracy: 1.0000
# Epoch 212/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.9758e-06 - categorical_accuracy: 1.0000
# Epoch 213/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 2.9407e-06 - categorical_accuracy: 1.0000
# Epoch 214/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.8902e-06 - categorical_accuracy: 1.0000
# Epoch 215/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.8650e-06 - categorical_accuracy: 1.0000
# Epoch 216/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.8314e-06 - categorical_accuracy: 1.0000
# Epoch 217/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.7921e-06 - categorical_accuracy: 1.0000
# Epoch 218/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.7444e-06 - categorical_accuracy: 1.0000
# Epoch 219/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.7248e-06 - categorical_accuracy: 1.0000
# Epoch 220/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.6799e-06 - categorical_accuracy: 1.0000
# Epoch 221/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.6575e-06 - categorical_accuracy: 1.0000
# Epoch 222/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 2.6196e-06 - categorical_accuracy: 1.0000
# Epoch 223/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 2.5888e-06 - categorical_accuracy: 1.0000
# Epoch 224/2000
# 3/3 [==============================] - 0s 56ms/step - loss: 2.5509e-06 - categorical_accuracy: 1.0000
# Epoch 225/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 2.5144e-06 - categorical_accuracy: 1.0000
# Epoch 226/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 2.5032e-06 - categorical_accuracy: 1.0000
# Epoch 227/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 2.4612e-06 - categorical_accuracy: 1.0000
# Epoch 228/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 2.4247e-06 - categorical_accuracy: 1.0000
# Epoch 229/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 2.4037e-06 - categorical_accuracy: 1.0000
# Epoch 230/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.3742e-06 - categorical_accuracy: 1.0000
# Epoch 231/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 2.3546e-06 - categorical_accuracy: 1.0000
# Epoch 232/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.3181e-06 - categorical_accuracy: 1.0000
# Epoch 233/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.2971e-06 - categorical_accuracy: 1.0000
# Epoch 234/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.2634e-06 - categorical_accuracy: 1.0000
# Epoch 235/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 2.2452e-06 - categorical_accuracy: 1.0000
# Epoch 236/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.2101e-06 - categorical_accuracy: 1.0000
# Epoch 237/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.1835e-06 - categorical_accuracy: 1.0000
# Epoch 238/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.1583e-06 - categorical_accuracy: 1.0000
# Epoch 239/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 2.1442e-06 - categorical_accuracy: 1.0000
# Epoch 240/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.1148e-06 - categorical_accuracy: 1.0000
# Epoch 241/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.0797e-06 - categorical_accuracy: 1.0000
# Epoch 242/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.0559e-06 - categorical_accuracy: 1.0000
# Epoch 243/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.0363e-06 - categorical_accuracy: 1.0000
# Epoch 244/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.0138e-06 - categorical_accuracy: 1.0000
# Epoch 245/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.9858e-06 - categorical_accuracy: 1.0000
# Epoch 246/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.9619e-06 - categorical_accuracy: 1.0000
# Epoch 247/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.9465e-06 - categorical_accuracy: 1.0000
# Epoch 248/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.9283e-06 - categorical_accuracy: 1.0000
# Epoch 249/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.8946e-06 - categorical_accuracy: 1.0000
# Epoch 250/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.8708e-06 - categorical_accuracy: 1.0000
# Epoch 251/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.8596e-06 - categorical_accuracy: 1.0000
# Epoch 252/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 1.8273e-06 - categorical_accuracy: 1.0000
# Epoch 253/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.8105e-06 - categorical_accuracy: 1.0000
# Epoch 254/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.7937e-06 - categorical_accuracy: 1.0000
# Epoch 255/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.7698e-06 - categorical_accuracy: 1.0000
# Epoch 256/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.7446e-06 - categorical_accuracy: 1.0000
# Epoch 257/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.7291e-06 - categorical_accuracy: 1.0000
# Epoch 258/2000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.7067e-06 - categorical_accuracy: 1.0000
# Epoch 259/2000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6955e-06 - categorical_accuracy: 1.0000
# Epoch 260/2000
# 1/3 [=========>....................] - ETA: 0s - loss: 7.5250e-07 - categorical_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32052/4079260596.py in <module>
# ----> 1 model.fit(x_train, y_train, epochs=2000, callbacks=[tb_callback])
#
# g:\python-projects\mediapipe-pose\venv\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# g:\python-projects\mediapipe-pose\venv\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# g:\python-projects\mediapipe-pose\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# g:\python-projects\mediapipe-pose\venv\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# g:\python-projects\mediapipe-pose\venv\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# g:\python-projects\mediapipe-pose\venv\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# g:\python-projects\mediapipe-pose\venv\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# g:\python-projects\mediapipe-pose\venv\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# g:\python-projects\mediapipe-pose\venv\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 30, 64)            50432
#
#  lstm_10 (LSTM)              (None, 30, 128)           98816
#
#  lstm_11 (LSTM)              (None, 64)                49408
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dense_10 (Dense)            (None, 32)                2080
#
#  dense_11 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 204,995
# Trainable params: 204,995
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = model.predict(x_test)

# %%
actions[np.argmax(res[4])]
# Out:
# 'Passive'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'Passive'

# %%
model.save('action.h5')

# %%
del model

# %%
model.load_weights('action.h5')

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 30, 64)            50432
#
#  lstm_13 (LSTM)              (None, 30, 128)           98816
#
#  lstm_14 (LSTM)              (None, 64)                49408
#
#  dense_12 (Dense)            (None, 64)                4160
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  dense_14 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 204,995
# Trainable params: 204,995
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(x_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
y_predicted = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, y_predicted)
# Out:
# array([[[4, 0],
#         [0, 1]],
#
#        [[2, 0],
#         [0, 3]],
#
#        [[4, 0],
#         [0, 1]]], dtype=int64)

# %%
accuracy_score(ytrue, y_predicted)
# Out:
# 1.0

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, pose)
        print(results)
        
        # Draw landmarks
        draw_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 3: 
                sentence = sentence[-3:]

            # Viz probabilities
#             image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Left Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Right Jab
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Passive

# %%
cap.release()
cv2.destroyAllWindows()
